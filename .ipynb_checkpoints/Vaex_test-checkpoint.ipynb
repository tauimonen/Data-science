# %%
# Testing Vaex

import vaex as vx
import pandas as pd
import numpy as np

# %%
rows = 1000000
cols = 20
df = pd.DataFrame(np.random.randint(100000000, 1000000000, size=(rows, cols)), columns=['c%d' % i for i in range(cols)])

# %%
df.to_csv("dataset.csv", index=False)

# %%
# %%time
vaex_df = vx.from_csv("dataset.csv", convert=True, chunk_size=5_000)

# %%
# %%timeit
# 12 GB
taxi1 = vx.open('s3://vaex/taxi/yellow_taxi_2015_f32s.hdf5?anon=true')
# Out:
# 23.1 ms ± 685 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
taxi1 = vx.open('s3://vaex/taxi/yellow_taxi_2015_f32s.hdf5?anon=true')
taxi1
# Out:
# #            vendor_id    pickup_datetime                dropoff_datetime               passenger_count    payment_type    trip_distance    pickup_longitude    pickup_latitude    rate_code    store_and_fwd_flag    dropoff_longitude    dropoff_latitude    fare_amount    surcharge    mta_tax    tip_amount    tolls_amount    total_amount
# 0            VTS          2014-12-16 02:26:00.000000000  2014-12-16 02:28:00.000000000  1                  CSH             1.09             -73.986725          40.75642           1.0          nan                   -73.99646            40.742893           5.0            0.5          0.5        0.0           0.0             6.0
# 1            VTS          2014-12-15 18:23:00.000000000  2014-12-15 18:58:00.000000000  2                                  6.28             -74.00419           40.72119           1.0          nan                   -73.97               nan                 nan            nan          nan        nan           nan             nan
# ...

# %%
# %%timeit
taxi2 = vx.open('s3://vaex/taxi/yellow_taxi_2009_2015_f32.hdf5?anon=true')
# Out:
# 26.1 ms ± 1.82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
taxi2 = vx.open('s3://vaex/taxi/yellow_taxi_2009_2015_f32.hdf5?anon=true')
taxi2
# Out:
# #              vendor_id    pickup_datetime                dropoff_datetime               passenger_count    payment_type    trip_distance    pickup_longitude    pickup_latitude    rate_code    store_and_fwd_flag    dropoff_longitude    dropoff_latitude    fare_amount    surcharge    mta_tax    tip_amount    tolls_amount    total_amount
# 0              VTS          2009-01-04 02:52:00.000000000  2009-01-04 03:02:00.000000000  1                  CASH            2.63             -73.99196           40.721565          nan          nan                   -73.993805           40.695923           8.9            0.5          nan        0.0           0.0             9.4
# ...

# %%
taxi2.shape
# Out:
# (1173057927, 18)

# %%
long_min = -74.05
long_max = -73.75
lat_min = 40.58
lat_max = 40.90

taxi1.viz.heatmap(taxi1.pickup_longitude, taxi1.pickup_latitude, f="log1p", limits=[[-74.05, -73.75], [40.58, 40.90]], show=True);
