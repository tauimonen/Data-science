# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cyclist.csv", sep=";")
a = df.replace(";;;;;;;;;;;;;;;;;;;;;",pd.np.nan)
df
# Out:
# <ipython-input-4-d4c6519ebe9f>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   a = df.replace(";;;;;;;;;;;;;;;;;;;;;",pd.np.nan)
#                   Päivämäärä  Auroransilta  Eteläesplanadi  \
# 0      ke 1 tammi 2014 00:00           NaN             7.0
# 1      ke 1 tammi 2014 01:00           NaN             5.0
# 2      ke 1 tammi 2014 02:00           NaN             2.0
# 3      ke 1 tammi 2014 03:00           NaN             5.0
# 4      ke 1 tammi 2014 04:00           NaN             1.0
# ...                      ...           ...             ...
# 37161                    NaN           NaN             NaN
# 37162                    NaN           NaN             NaN
# 37163                    NaN           NaN             NaN
# 37164                    NaN           NaN             NaN
# 37165                    NaN           NaN             NaN
#
# ...
